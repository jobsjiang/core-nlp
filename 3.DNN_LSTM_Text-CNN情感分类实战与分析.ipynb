# %% [markdown]
# https://mp.weixin.qq.com/s/9w7PvcqpxPkZtwgCqPhXTQ

# %%
import tqdm
from collections import Counter
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
# Out:
# C:\Users\jianghaitao1\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\jianghaitao1\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\jianghaitao1\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\jianghaitao1\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\jianghaitao1\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\jianghaitao1\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\jianghaitao1\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# 加载数据
# pos数据
with open("../dataset/pos.txt", "r",encoding='utf-8') as f:
    pos_text = f.read()

# neg数据
with open("../dataset/neg.txt", "r",encoding='utf-8') as f:
    neg_text = f.read()

# %%
# 描述性统计
# 积极文本统计
print("-" * 20 + " POSITIVE TEXT " + "-" * 20)
# 分句
pos_sentences = pos_text.lower().split("\n")
print("Total positive sentences: {}".format(len(pos_sentences)))
print("The average length of positive sentences: {}".format(np.mean([len(sentence.split()) for sentence in pos_sentences])))
print("The max length of positive sentences: {}".format(np.max([len(sentence.split()) for sentence in pos_sentences])))
print("The min length of positive sentences: {}".format(np.min([len(sentence.split()) for sentence in pos_sentences])))
# 统计高频词
c = Counter(pos_text.split()).most_common(100)
print("Most common words in positive sentences: \n{}".format(c))

# 校级文本统计
print()
print("-" * 20 + " NEGATIVE TEXT " + "-" * 20)
# 分句
neg_sentences = neg_text.lower().split("\n")
print("Total negative sentences: {}".format(len(neg_sentences)))
print("The average length of negative sentences: {}".format(np.mean([len(sentence.split()) for sentence in neg_sentences])))
print("The max length of negative sentences: {}".format(np.max([len(sentence.split()) for sentence in neg_sentences])))
print("The min length of negative sentences: {}".format(np.min([len(sentence.split()) for sentence in neg_sentences])))
# 统计高频词
c = Counter(neg_text.split()).most_common(100)
print("Most common words in negative sentences: \n{}".format(c))
# Out:
# -------------------- POSITIVE TEXT --------------------
# Total positive sentences: 5331
# The average length of positive sentences: 21.0921027949728
# The max length of positive sentences: 59
# The min length of positive sentences: 2
# Most common words in positive sentences:
# [('.', 6972), (',', 5268), ('the', 5051), ('a', 3830), ('and', 3548), ('of', 3311), ('to', 1969), ('is', 1707), ('in', 1338), ('that', 1262), ('it', 1100), ('with', 883), ('as', 879), ('film', 822), ('but', 782), ('an', 754), ('its', 699), ('for', 673), ('this', 666), ("it's", 564), ('movie', 510), ('you', 494), ('on', 424), ('be', 419), ('by', 380), ('has', 379), ('not', 367), ('one', 366), ('at', 366), ('about', 363), ('from', 349), ('are', 348), ('his', 344), ('"', 330), ('--', 319), ('more', 311), ('all', 289), ('than', 282), ('like', 281), ('if', 264), ('have', 259), ('story', 256), ('who', 247), ('most', 240), ('what', 225), ('into', 213), ('so', 209), ('will', 199), ('good', 198), ('comedy', 192), ('or', 189), ('i', 181), ('funny', 181), ('even', 180), ('out', 178), ('their', 175), ('best', 166), ('can', 166), ('some', 164), ('way', 164), ('time', 158), ('us', 156), ('much', 154), ('up', 154), ('make', 151), ('love', 149), ('just', 148), ('makes', 144), ('life', 144), ('characters', 144), ('may', 141), ('work', 139), ('performances', 138), ('your', 135), ('very', 135), ('little', 129), ('enough', 127), ('while', 123), ('her', 123), ('no', 120), ('still', 120), ('director', 119), ('look', 119), ('there', 118), ('well', 117), ('both', 114), ('fun', 113), ('movies', 111), ('drama', 111), ('new', 110), ('never', 110), ('those', 109), ('films', 109), ('we', 108), ('when', 107), ('great', 105), ('(', 104), (')', 104), ('which', 104), ('only', 103)]
#
# -------------------- NEGATIVE TEXT --------------------
# Total negative sentences: 5331
# The average length of negative sentences: 20.93884824610767
# The max length of negative sentences: 56
# The min length of negative sentences: 1
# Most common words in negative sentences:
# [('.', 7038), ('the', 5045), (',', 4769), ('a', 3451), ('of', 2750), ('and', 2647), ('to', 2264), ('is', 1660), ('in', 1290), ('that', 1208), ('it', 1181), ('as', 922), ('but', 855), ('this', 774), ('for', 763), ('movie', 758), ('with', 677), ('its', 636), ('film', 623), ('an', 567), ("it's", 555), ('be', 520), ('on', 471), ('like', 439), ('not', 436), ('more', 416), ('by', 415), ('you', 398), ('than', 382), ('about', 370), ('too', 365), ('have', 364), ('one', 361), ('are', 360), ('all', 352), ('so', 346), ('at', 339), ('or', 330), ('has', 330), ('"', 325), ('from', 324), ('--', 310), ('just', 290), ('i', 285), ('his', 284), ('if', 273), ('no', 267), ('much', 232), ('up', 222), ('story', 220), ('out', 220), ('bad', 206), ('only', 205), ('into', 204), ('even', 202), ('what', 188), ('who', 185), ('time', 181), ('good', 179), ('will', 175), ('little', 173), ('can', 171), ('some', 170), ('been', 169), ('characters', 169), ('?', 167), ('most', 162), ('comedy', 161), ('when', 155), ("doesn't", 153), ('never', 152), ('would', 148), ('was', 143), ('enough', 140), ('which', 137), ("there's", 137), ('he', 137), ('there', 132), ('way', 132), ('very', 130), ('really', 130), ('your', 129), ('any', 128), ('make', 127), (':', 124), (')', 124), ('they', 123), ('(', 122), ('nothing', 121), ('plot', 120), ('their', 117), ("isn't", 116), ('should', 116), ('could', 115), ('every', 114), ('something', 113), ('director', 112), ('made', 109), ('we', 109), ('through', 108)]

# %% [markdown]
# ### 数据预处理
# * 构造词典Vocabulary
# * 构造映射表
# * 转换单词为tokens

# %%
# 句子最大长度
SENTENCE_LIMIT_SIZE = 20

# %% [markdown]
# ####  构造词典
# 我们要基于整个语料来构造我们的词典，由于文本中包含许多干扰词汇，例如仅出现过1次的这类单词。对于这类极其低频词汇，我们可以对其进行去除，一方面能加快模型执行效率，一方面也能减少特殊词带来的噪声。

# %%
# 合并pos和neg文本
total_text = pos_text + "\n" + neg_text
# 统计词汇
c = Counter(total_text.split())

# %%
# 倒序查看词频
sorted(c.most_common(), key=lambda x: x[1])
# Out:
# [("century's", 1),
#  ('jean-claud', 1),
#  ('segal', 1),
#  ('middle-earth', 1),
#  ('too-tepid', 1),
#  ('showed', 1),
#  ('curls', 1),
#  ('fed', 1),
#  ('ponders', 1),
#  ("it'", 1),
#  ('enrapturing', 1),
#  ('tempt', 1),
#  ('inscrutable', 1),
#  ('spiderman', 1),
#  ('latent', 1),
#  ('gangsta', 1),
#  ('shook', 1),
#  ('rattled', 1),
#  ('deceptive', 1),
#  ('grimness', 1),
#  ('fatalist', 1),
#  ('worldview', 1),
#  ('lobbies', 1),
#  ('two-lane', 1),
#  ('roadside', 1),
#  ('cafes', 1),
#  ('permeate', 1),
#  ('bona-fide', 1),
#  ('outings', 1),
#  ('cartoonlike', 1),
#  ('magnet', 1),
#  ('co-star', 1),
#  ("'compleja", 1),
#  ('intelectualmente', 1),
#  ('retadora', 1),
#  ('ladrón', 1),
#  ('orquídeas', 1),
#  ('esos', 1),
#  ('filmes', 1),
#  ('precisamente', 1),
#  ('originalidad', 1),
#  ('karmen', 1),
#  ('chanting', 1),
#  ('braided', 1),
#  ('wipe', 1),
#  ('jeweled', 1),
#  ('beads', 1),
#  ('lacerating', 1),
#  ("'50's", 1),
#  ('cheesiness', 1),
#  ("johnson's", 1),
#  ('orchestrates', 1),
#  ('siberian', 1),
#  ('sheep', 1),
#  ('hosts', 1),
#  ('parka-wrapped', 1),
#  ('everytime', 1),
#  ('singer/composer', 1),
#  ('contributes', 1),
#  ('slew', 1),
#  ('intrusive', 1),
#  ('enlightened', 1),
#  ("derrida's", 1),
#  ("1998's", 1),
#  ('chiaroscuro', 1),
#  ('uncontrolled', 1),
#  ('farther', 1),
#  ('quietness', 1),
#  ('domineering', 1),
#  ("mother's", 1),
#  ('shadings', 1),
#  ('coloring', 1),
#  ('treebeard', 1),
#  ("'performance'", 1),
#  ('ingeniously', 1),
#  ('aberration', 1),
#  ('originally', 1),
#  ('comedy/thriller', 1),
#  ('orchestrate', 1),
#  ('overpraised', 1),
#  ('catchy', 1),
#  ('spycraft', 1),
#  ("damon's", 1),
#  ('katz', 1),
#  ('lynchings', 1),
#  ('reel-to-reel', 1),
#  ('recordings', 1),
#  ('meeropol', 1),
#  ('anthropologically', 1),
#  ("early-'80s", 1),
#  ('suburbia', 1),
#  ('interstitial', 1),
#  ('vertiginous', 1),
#  ('embers', 1),
#  ('dormant', 1),
#  ('calcified', 1),
#  ('chronic', 1),
#  ("irwin's", 1),
#  ('hemmingway', 1),
#  ('accelerated', 1),
#  ('lovers-on-the-run', 1),
#  ("piesiewicz's", 1),
#  ('veronique', 1),
#  ('again-courage', 1),
#  ('sl2', 1),
#  ('self-contained', 1),
#  ('pabst', 1),
#  ('ribbon', 1),
#  ('du', 1),
#  ('sarcasm', 1),
#  ('quizzical', 1),
#  ('syncopated', 1),
#  ('mimicking', 1),
#  ('memory-as-identity', 1),
#  ('obviation', 1),
#  ('long-held', 1),
#  ('illusions', 1),
#  ('erasing', 1),
#  ('recasts', 1),
#  ('gambol', 1),
#  ('fluidly', 1),
#  ('b-scene', 1),
#  ('digital-video', 1),
#  ('comedians', 1),
#  ("'truth'", 1),
#  ('deconstructing', 1),
#  ('blessing', 1),
#  ('thunderous', 1),
#  ('cadences', 1),
#  ('shortage', 1),
#  ('responsive', 1),
#  ('koreans', 1),
#  ('gourmet', 1),
#  ('drive-thru', 1),
#  ('strap', 1),
#  ('frontier', 1),
#  ('logistical', 1),
#  ('milestone', 1),
#  ('[schweiger', 1),
#  ('steak', 1),
#  ('minefield', 1),
#  ('gorefests', 1),
#  ('connoisseur', 1),
#  ('lo-fi', 1),
#  ('15-cent', 1),
#  ('stump', 1),
#  ('hogs', 1),
#  ('conan-esque', 1),
#  ('partially', 1),
#  ('minty', 1),
#  ('prizes', 1),
#  ('rambunctious', 1),
#  ('non-jew', 1),
#  ('happiest', 1),
#  ('[but', 1),
#  ("it's]", 1),
#  ('backs', 1),
#  ('commodity', 1),
#  ('homespun', 1),
#  ('mule', 1),
#  ('skinner', 1),
#  ('posse', 1),
#  ('seaworthy', 1),
#  ('sock-you-in-the-eye', 1),
#  ('non-reactionary', 1),
#  ('near-disaster', 1),
#  ('makmalbaf', 1),
#  ('kurdish', 1),
#  ('borderlands', 1),
#  ('chunk', 1),
#  ('pinch', 1),
#  ('tartness', 1),
#  ('tribulations', 1),
#  ("comedy'", 1),
#  ("willams'", 1),
#  ('ebb', 1),
#  ('deposits', 1),
#  ('[jack', 1),
#  ("nicholson's]", 1),
#  ('20-year-old', 1),
#  ('exhilarate', 1),
#  ('beanie', 1),
#  ('ever-escalating', 1),
#  ('latifah', 1),
#  ('flaunting', 1),
#  ('actor/director', 1),
#  ('giles', 1),
#  ('nuttgens', 1),
#  ('contradictions', 1),
#  ('lump-in-the-throat', 1),
#  ('diverted', 1),
#  ('lightens', 1),
#  ('bigger-than-life', 1),
#  ('questing', 1),
#  ('racked', 1),
#  ('genet', 1),
#  ('rechy', 1),
#  ('fassbinder', 1),
#  ('nocturnal', 1),
#  ('goya', 1),
#  ('badge', 1),
#  ('permutations', 1),
#  ('[drumline]', 1),
#  ('headlines', 1),
#  ('1995', 1),
#  ('disapproval', 1),
#  ('tinge', 1),
#  ('crystalline', 1),
#  ('three-year-old', 1),
#  ('fictionalize', 1),
#  ('visits', 1),
#  ('slice-of-depression', 1),
#  ('grasped', 1),
#  ('composing', 1),
#  ('preteens', 1),
#  ("o's", 1),
#  ('knock-offs', 1),
#  ('political-action', 1),
#  ('fastidiousness', 1),
#  ('ellefsen', 1),
#  ('frailties', 1),
#  ('magnified', 1),
#  ('vex', 1),
#  ("petin's", 1),
#  ('penetrates', 1),
#  ('tantalizing', 1),
#  ('provocatuers', 1),
#  ('aroused', 1),
#  ('mideast', 1),
#  ('perceptively', 1),
#  ('jirí', 1),
#  ("hubac's", 1),
#  ('silberstein', 1),
#  ('additional', 1),
#  ('shapelessly', 1),
#  ('gratifying', 1),
#  ('appraisal', 1),
#  ('anti-date', 1),
#  ('intently', 1),
#  ('regimes', 1),
#  ('figurative', 1),
#  ('port-of-call', 1),
#  ('even-handed', 1),
#  ('dock', 1),
#  ('unloading', 1),
#  ('greek-american', 1),
#  ('testify', 1),
#  ('comparative', 1),
#  ('inhabited', 1),
#  ('venomous', 1),
#  ('bigotries', 1),
#  ('theocracy', 1),
#  ('antithesis', 1),
#  ('dazzlingly', 1),
#  ("münch's", 1),
#  ('overindulgence', 1),
#  ('deteriorating', 1),
#  ('croc', 1),
#  ('disrupts', 1),
#  ('re-enactments', 1),
#  ('character-based', 1),
#  ('endearingly', 1),
#  ('post-soviet', 1),
#  ('russia', 1),
#  ('bishop', 1),
#  ('standouts', 1),
#  ('bastions', 1),
#  ('ikea', 1),
#  ('blurred', 1),
#  ('razor', 1),
#  ('transferral', 1),
#  ('spy-on-the-run', 1),
#  ('sanded', 1),
#  ('microcosm', 1),
#  ('dabbling', 1),
#  ('authors', 1),
#  ('battista', 1),
#  ('directress', 1),
#  ('breezily', 1),
#  ('apolitical', 1),
#  ('gawk', 1),
#  ('wallpaper', 1),
#  ('hu', 1),
#  ('matter-of-fact', 1),
#  ('glint', 1),
#  ('raja', 1),
#  ('enthuse', 1),
#  ("andersson's", 1),
#  ('rigorous', 1),
#  ('distancing', 1),
#  ('real-live', 1),
#  ('movingly', 1),
#  ('179-minute', 1),
#  ('institution--acted', 1),
#  ('weakened', 1),
#  ('supportive', 1),
#  ('40-minute', 1),
#  ('valedictory', 1),
#  ('bargain', 1),
#  ('shards', 1),
#  ('gyro', 1),
#  ("'bartleby'", 1),
#  ('farrell', 1),
#  ('foil', 1),
#  ("willis's", 1),
#  ('world-weary', 1),
#  ('colonel', 1),
#  ('conditioned', 1),
#  ('saucer-eyed', 1),
#  ('downy-cheeked', 1),
#  ('moppets', 1),
#  ('sugar-free', 1),
#  ('post-breakup', 1),
#  ("sayles'", 1),
#  ('wordplay', 1),
#  ('preference', 1),
#  ('indomitable', 1),
#  ('ostentatious', 1),
#  ("african-american's", 1),
#  ('randy', 1),
#  ('figuratively', 1),
#  ('[sex', 1),
#  ('lucía]', 1),
#  ('arousing', 1),
#  ('andré', 1),
#  ('turpin', 1),
#  ("renner's", 1),
#  ('award-worthy', 1),
#  ('rhythmic', 1),
#  ('adulthood', 1),
#  ('fraught', 1),
#  ('wannabes', 1),
#  ('addessi', 1),
#  ('beatrice', 1),
#  ("jones'", 1),
#  ('melding', 1),
#  ('reflecting', 1),
#  ('heartbeat-like', 1),
#  ('whole-heartedly', 1),
#  ('movie--', 1),
#  ('longley', 1),
#  ('horrifically', 1),
#  ("crowd-pleaser's", 1),
#  ('gruelling', 1),
#  ("wollter's", 1),
#  ('euro-film', 1),
#  ('rockwell', 1),
#  ('vastness', 1),
#  ('green-guts', 1),
#  ('beaut', 1),
#  ('bundy', 1),
#  ('reilly', 1),
#  ('octopus', 1),
#  ('deceivingly', 1),
#  ('retrospect', 1),
#  ('ana', 1),
#  ('[anderson]', 1),
#  ('ho-tep', 1),
#  ('likability', 1),
#  ('increments', 1),
#  ('camouflaged', 1),
#  ("'brazil", 1),
#  ('goddammit', 1),
#  ('adoration', 1),
#  ('hogwarts', 1),
#  ('mischief', 1),
#  ('heart-on-its-sleeve', 1),
#  ('redgrave', 1),
#  ('aquatic', 1),
#  ('baja', 1),
#  ('peninsula', 1),
#  ('mexico', 1),
#  ('hyper-time', 1),
#  ('grenier', 1),
#  ('heidegger-', 1),
#  ('nietzsche-referencing', 1),
#  ('patois', 1),
#  ('mullinski', 1),
#  ('compact', 1),
#  ('breezes', 1),
#  ('imagining', 1),
#  ('sardine', 1),
#  ("'face", 1),
#  ("value'", 1),
#  ('wimp', 1),
#  ('cried', 1),
#  ('heart-affecting', 1),
#  ('displayed', 1),
#  ('33-year-old', 1),
#  ('inexperience', 1),
#  ('division', 1),
#  ('risk-takers', 1),
#  ('sandwiched', 1),
#  ('heart-rending', 1),
#  ('buzz-obsessed', 1),
#  ('descend', 1),
#  ('utah', 1),
#  ('ferret', 1),
#  ("'tadpole'", 1),
#  ('declared', 1),
#  ("elliott's", 1),
#  ('fashions', 1),
#  ('character-', 1),
#  ('and-', 1),
#  ('connects', 1),
#  ('double-crosses', 1),
#  ('ranging', 1),
#  ('gathers', 1),
#  ("l'avventura", 1),
#  ('repulsion', 1),
#  ('congeals', 1),
#  ('tingle', 1),
#  ("'barbershop'", 1),
#  ('anytime', 1),
#  ('narcotizing', 1),
#  ('ensnaring', 1),
#  ('[taymor]', 1),
#  ('utilizes', 1),
#  ('catapulting', 1),
#  ('eye-opening', 1),
#  ('oblivion', 1),
#  ('examined', 1),
#  ("villeneuve's", 1),
#  ('sugar-coating', 1),
#  ('[villeneuve]', 1),
#  ('intuitively', 1),
#  ('squalor', 1),
#  ('bared', 1),
#  ('confronted', 1),
#  ('code-talk', 1),
#  ('out-stealth', 1),
#  ('precollegiate', 1),
#  ('liberated', 1),
#  ("hogan's", 1),
#  ("reno's", 1),
#  ('suffused', 1),
#  ('trumpets', 1),
#  ('go-round', 1),
#  ('headlong', 1),
#  ('delinquent', 1),
#  ('peter/spider-man', 1),
#  ('myths', 1),
#  ('afresh', 1),
#  ('arouse', 1),
#  ('unknowing', 1),
#  ('[sinks]', 1),
#  ('resolute', 1),
#  ('nakedness', 1),
#  ('interwoven…', 1),
#  ('positions', 1),
#  ('stimulates', 1),
#  ('unobtrusively', 1),
#  ("version's", 1),
#  ('plentiful', 1),
#  ('provide[s]', 1),
#  ('technology-of-the-moment', 1),
#  ('manipulate', 1),
#  ('saturation', 1),
#  ("glass'", 1),
#  ('divining', 1),
#  ('confirmation', 1),
#  ('unelected', 1),
#  ('incurious', 1),
#  ('uncharismatic', 1),
#  ('overgrown', 1),
#  ('whiplash', 1),
#  ('time-honored', 1),
#  ('bowel-curdling', 1),
#  ('heart-stopping', 1),
#  ('unmentioned', 1),
#  ('amalgamating', 1),
#  ('not-so-stock', 1),
#  ('super-cool', 1),
#  ('relax', 1),
#  ('undoubted', 1),
#  ('extensions', 1),
#  ('charmers', 1),
#  ('pencil-thin', 1),
#  ('pro-fat', 1),
#  ('sparklingly', 1),
#  ('consciousness-raiser', 1),
#  ('bonehead', 1),
#  ('deciding', 1),
#  ('affirmation', 1),
#  ('good-deed/bad-deed', 1),
#  ('reversals', 1),
#  ('sinner', 1),
#  ('symmetrical', 1),
#  ('cross-shaped', 1),
#  ('unaccustomed', 1),
#  ('contests', 1),
#  ("griffin's", 1),
#  ('testimonials', 1),
#  ('arena', 1),
#  ('barrett', 1),
#  ('browning', 1),
#  ('hmm', 1),
#  ('800-page', 1),
#  ('nurturing', 1),
#  ('gauzy', 1),
#  ('dithering', 1),
#  ('zigs', 1),
#  ('zags', 1),
#  ('laser-projected', 1),
#  ('spell-casting', 1),
#  ('dreyfus', 1),
#  ('grader', 1),
#  ('b-minus', 1),
#  ('patterns', 1),
#  ('ideals', 1),
#  ('fatality', 1),
#  ('classism', 1),
#  ('ignorance', 1),
#  ('meat-and-potatoes', 1),
#  ('shticks', 1),
#  ('sympathetically', 1),
#  ('[gai]', 1),
#  ('personifying', 1),
#  ('intimidating', 1),
#  ('horror/thriller', 1),
#  ('well-known', 1),
#  ('blobby', 1),
#  ('superlarge', 1),
#  ('changer', 1),
#  ('self-evaluation', 1),
#  ('guidance', 1),
#  ('invade', 1),
#  ('mindsets', 1),
#  ('fanatically', 1),
#  ('fetishized', 1),
#  ('old-movie', 1),
#  ('idiosyncrasy', 1),
#  ('monastic', 1),
#  ('peter]', 1),
#  ('majesty', 1),
#  ('slipper', 1),
#  ('holidays', 1),
#  ('incarnates', 1),
#  ('prophetic', 1),
#  ('exacting', 1),
#  ('patronized', 1),
#  ('crafts', 1),
#  ('‘what', 1),
#  ("see'", 1),
#  ('incandescent', 1),
#  ('stupendous', 1),
#  ('unsettling--but', 1),
#  ('unquestionably', 1),
#  ('13-year-old', 1),
#  ('bedouins', 1),
#  ('wide-ranging', 1),
#  ('non-shakespeare', 1),
#  ('softest', 1),
#  ('revolt', 1),
#  ('off-the-cuff', 1),
#  ('gunning', 1),
#  ("bow's", 1),
#  ('preschool', 1),
#  ('good-humored', 1),
#  ('charmingly', 1),
#  ('bola', 1),
#  ('peeved', 1),
#  ('nalin', 1),
#  ('crime-film', 1),
#  ('loosey-goosey', 1),
#  ('is…', 1),
#  ('destinees', 1),
#  ('bedevils', 1),
#  ('77-minute', 1),
#  ('40-year-old', 1),
#  ('soldier', 1),
#  ('45-minute', 1),
#  ('teamwork', 1),
#  ('molony', 1),
#  ('parisian', 1),
#  ('pg-rated', 1),
#  ('ensnared', 1),
#  ('ferocious', 1),
#  ('gosh', 1),
#  ('quests', 1),
#  ('courting', 1),
#  ('preposterousness', 1),
#  ('interference', 1),
#  ('margolo', 1),
#  ('computer-animated', 1),
#  ('self-actualization', 1),
#  ('continental', 1),
#  ('divides', 1),
#  ('profiles', 1),
#  ("another's", 1),
#  ('screen-eating', 1),
#  ('dominatrixes', 1),
#  ('tango', 1),
#  ('camera-work', 1),
#  ('characterizing', 1),
#  ('knots', 1),
#  ('mock-tarantino', 1),
#  ('scuzbag', 1),
#  ('delicacy', 1),
#  ('surpassed', 1),
#  ('empress', 1),
#  ("leoni's", 1),
#  ('ellie', 1),
#  ('recapturing', 1),
#  ('pauses', 1),
#  ('locked', 1),
#  ('cat-and-cat', 1),
#  ("herek's", 1),
#  ('bottles', 1),
#  ("hornby's", 1),
#  ('drop-dead', 1),
#  ('idoosyncratic', 1),
#  ('terrain', 1),
#  ('flatula', 1),
#  ('advises', 1),
#  ('denlopp', 1),
#  ('deckhand', 1),
#  ('updatings', 1),
#  ("silver's", 1),
#  ('parrot', 1),
#  ('mimics', 1),
#  ("trio's", 1),
#  ("niccol's", 1),
#  ('anti-hollywood', 1),
#  ("screenplay's", 1),
#  ('sappier', 1),
#  ("hook's", 1),
#  ('assuredness', 1),
#  ('uninhibited', 1),
#  ('pigeonhole-resisting', 1),
#  ('antidotes', 1),
#  ('11-year-old', 1),
#  ('convert', 1),
#  ('elmer', 1),
#  ("bernstein's", 1),
#  ('melodic', 1),
#  ('10-inch', 1),
#  ('edge-of-your-seat', 1),
#  ('shambling', 1),
#  ('custom-made', 1),
#  ('hornby', 1),
#  ('belated', 1),
#  ('all-stars', 1),
#  ("ride's", 1),
#  ('lap', 1),
#  ('gotta', 1),
#  ("carion's", 1),
#  ('hums', 1),
#  ('buena', 1),
#  ('oportunidad', 1),
#  ('cultura', 1),
#  ('aunque', 1),
#  ('condensada', 1),
#  ('aprovechar', 1),
#  ('dyspeptic', 1),
#  ('visualmente', 1),
#  ('espectacular', 1),
#  ('entretenida', 1),
#  ('te', 1),
#  ('sorprenderá', 1),
#  ('theirs', 1),
#  ('mirth', 1),
#  ('frisky', 1),
#  ('exporing', 1),
#  ('chin', 1),
#  ('marketplace', 1),
#  ('amusingly', 1),
#  ("anymore'", 1),
#  ('shading', 1),
#  ('[fessenden]', 1),
#  ("ross's", 1),
#  ('specials', 1),
#  ('entrancing', 1),
#  ('darn', 1),
#  ('smarty-pants', 1),
#  ('agreeable', 1),
#  ('time-wasting', 1),
#  ("pal's", 1),
#  ('heartbeat', 1),
#  ('inequities', 1),
#  ('immorality', 1),
#  ('administration', 1),
#  ('misperception', 1),
#  ('shinya', 1),
#  ("tsukamoto's", 1),
#  ('180', 1),
#  ('fiascoes', 1),
#  ('opera-to-film', 1),
#  ('heaving', 1),
#  ('love-jealousy-', 1),
#  ('murder-suicide', 1),
#  ('fandango', 1),
#  ('abbas', 1),
#  ("'charly'", 1),
#  ('befuddlement', 1),
#  ('marvellous', 1),
#  ('mind-blowing', 1),
#  ('breath-taking', 1),
#  ('earthshaking', 1),
#  ('fluctuating', 1),
#  ('humanitarian', 1),
#  ("'co-stars", 1),
#  ('unlucky', 1),
#  ('cassette', 1),
#  ('def', 1),
#  ("leppard's", 1),
#  ('pyromania', 1),
#  ('fandom', 1),
#  ('combo', 1),
#  ('closeness', 1),
#  ('unreality', 1),
#  ('broken-down', 1),
#  ('andersson', 1),
#  ('hoops', 1),
#  ('plump', 1),
#  ('fulsome', 1),
#  ('reinforced', 1),
#  ('all-ages', 1),
#  ('quantum', 1),
#  ('slash-dash', 1),
#  ('potholes', 1),
#  ('befall', 1),
#  ('brethren', 1),
#  ('turfs', 1),
#  ('self-made', 1),
#  ('low-down', 1),
#  ('reviewing', 1),
#  ('obscurities', 1),
#  ('slam-bam', 1),
#  ('miniscule', 1),
#  ('bleep', 1),
#  ('capturou', 1),
#  ('pomo', 1),
#  ('ouro', 1),
#  ('well-oiled', 1),
#  ('upholstered', 1),
#  ('sickness', 1),
#  ('rara', 1),
#  ('avis', 1),
#  ('articulated', 1),
#  ('flights', 1),
#  ('utmost', 1),
#  ('economy', 1),
#  ('samantha', 1),
#  ('viewfinder', 1),
#  ("master's", 1),
#  ('sarcástica', 1),
#  ('demencial', 1),
#  ('predecesora', 1),
#  ('ejemplo', 1),
#  ('entretenimiento', 1),
#  ('puro', 1),
#  ('complejos', 1),
#  ("obsessive-compulsive's", 1),
#  ('cadness', 1),
#  ('westfeldt', 1),
#  ('juergensen', 1),
#  ('israeli-occupied', 1),
#  ('territories', 1),
#  ('crit', 1),
#  ("'types'", 1),
#  ('elizabethan', 1),
#  ('shagster', 1),
#  ('casey', 1),
#  ('kasem-furnished', 1),
#  ('amongst', 1),
#  ('self-interest', 1),
#  ('representations', 1),
#  ('contacts', 1),
#  ("'hosts'", 1),
#  ("'guests", 1),
#  ('tastes', 1),
#  ('foreboding', 1),
#  ('jazzes', 1),
#  ('madame', 1),
#  ('refer', 1),
#  ("'jackie'", 1),
#  ('spates', 1),
#  ('translates', 1),
#  ("hors-d'oeuvre", 1),
#  ('self-dramatizing', 1),
#  ('filmic', 1),
#  ('playboy', 1),
#  ('quintessentially', 1),
#  ('underlay', 1),
#  ('gaiety', 1),
#  ('[broomfield]', 1),
#  ('sizzling', 1),
#  ('sweet-natured', 1),
#  ("francisco's", 1),
#  ('fountainheads', 1),
#  ('pawns', 1),
#  ('bishops', 1),
#  ('kings', 1),
#  ('wagers', 1),
#  ('dingy', 1),
#  ('backrooms', 1),
#  ('forests', 1),
#  ('reject', 1),
#  ("python's", 1),
#  ('discontented', 1),
#  ("1983's", 1),
#  ('koyaanisqatsi', 1),
#  ("1988's", 1),
#  ('powaqqatsi', 1),
#  ('naqoyqatsi', 1),
#  ('nations', 1),
#  ('inventively', 1),
#  ('fleet', 1),
#  ('extols', 1),
#  ('comradeship', 1),
#  ('retribution', 1),
#  ('futures', 1),
#  ('children--and', 1),
#  ('policiales', 1),
#  ('últimos', 1),
#  ('tiempos', 1),
#  ('modulated', 1),
#  ('under-12', 1),
#  ('caper-comedy', 1),
#  ('laugh-filled', 1),
#  ('kaputschnik', 1),
#  ('renown', 1),
#  ('dolgin', 1),
#  ('vietnamese-born', 1),
#  ('eagerly', 1),
#  ('all-american', 1),
#  ('infecting', 1),
#  ('pasadena', 1),
#  ('horror-comedy', 1),
#  ("elvira's", 1),
#  ('hooters', 1),
#  ('binds', 1),
#  ('grass', 1),
#  ('2--quite', 1),
#  ('south-of-the-border', 1),
#  ('melrose', 1),
#  ('erika', 1),
#  ('mini-mod-madness', 1),
#  ('kickass', 1),
#  ('beau', 1),
#  ('travil', 1),
#  ('nenette', 1),
#  ('boni', 1),
#  ('perverted', 1),
#  ('sex-soaked', 1),
#  ('creator', 1),
#  ('simplest', 1),
#  ("australia's", 1),
#  ('flaky', 1),
#  ('bizarrely', 1),
#  ('side-splittingly', 1),
#  ('piper', 1),
#  ('perabo', 1),
#  ('sugar-sweet', 1),
#  ('magnificence', 1),
#  ('chorus', 1),
#  ('damsels', 1),
#  ('premier', 1),
#  ('sarcastic', 1),
#  ('shield', 1),
#  ('middle-fingered', 1),
#  ('outta', 1),
#  ('am-radio', 1),
#  ('tierney', 1),
#  ('engulfing', 1),
#  ('allying', 1),
#  ('defeat', 1),
#  ('resonates', 1),
#  ('renoir', 1),
#  ('non-actors', 1),
#  ('no-budget', 1),
#  ('subtleties', 1),
#  ("ramsay's", 1),
#  ('resent', 1),
#  ('professes', 1),
#  ('giddily', 1),
#  ('francophiles', 1),
#  ('snicker', 1),
#  ('knowingly', 1),
#  ('caution', 1),
#  ('hedonist', 1),
#  ('aborbing', 1),
#  ('arguable', 1),
#  ('hallucinations', 1),
#  ('electrocute', 1),
#  ('dismember', 1),
#  ('avert', 1),
#  ('mass-market', 1),
#  ('child-centered', 1),
#  ('toe-tapping', 1),
#  ('long-range', 1),
#  ('1955', 1),
#  ('monkeyfun', 1),
#  ('bounties', 1),
#  ('artifacts', 1),
#  ("petersburg's", 1),
#  ("[hawn's", 1),
#  ('character]is', 1),
#  ('bluntly', 1),
#  ('new/old', 1),
#  ('exigencies', 1),
#  ('adorned', 1),
#  ('full-on', 1),
#  ('pleasurably', 1),
#  ('jacked-up', 1),
#  ('philibert', 1),
#  ('observes', 1),
#  ('schoolhouse', 1),
#  ('dainty', 1),
#  ('psychopathy', 1),
#  ('ecologically', 1),
#  ('unconventionally', 1),
#  ('half-wit', 1),
#  ('venerable', 1),
#  ('never-ending', 1),
#  ('reheated', 1),
#  ('weeping', 1),
#  ("more's", 1),
#  ('relaxing', 1),
#  ('viewings', 1),
#  ('lauren', 1),
#  ('puzzlement', 1),
#  ('symbolizes', 1),
#  ("alzheimer's", 1),
#  ('interacting', 1),
#  ('eyeball-to-eyeball', 1),
#  ('toe-to-toe', 1),
#  ("dragon'", 1),
#  ('open-endedness', 1),
#  ('11th', 1),
#  ('barbecue', 1),
#  ('single-mindedly', 1),
#  ('presuppose', 1),
#  ('bigotry', 1),
#  ('zealous', 1),
#  ('nuttiness', 1),
#  ('antagonists', 1),
#  ('impartiality', 1),
#  ('armenian-canadian', 1),
#  ('broached', 1),
#  ('nonagenarian', 1),
#  ('boldness', 1),
#  ('pentecostal', 1),
#  ('dallas', 1),
#  ('services', 1),
#  ('warthog', 1),
#  ('hyperbole', 1),
#  ('bravely', 1),
#  ('delve', 1),
#  ('fictions', 1),
#  ('peddled', 1),
#  ("'have-yourself-a-happy-little-holocaust'", 1),
#  ('jakob', 1),
#  ('allegorical', 1),
#  ('quench', 1),
#  ('josef', 1),
#  ('bierbichler', 1),
#  ('monica', 1),
#  ('bleibtreu', 1),
#  ('helene', 1),
#  ('weigel', 1),
#  ('richest', 1),
#  ("[ricci's]", 1),
#  ('girl-woman', 1),
#  ('thwart', 1),
#  ('crummles', 1),
#  ('[howard]', 1),
#  ('crossing', 1),
#  ('gut-bustingly', 1),
#  ('thinnest', 1),
#  ('sleepy', 1),
#  ('declares', 1),
#  ('yang', 1),
#  ('expressed', 1),
#  ('82', 1),
#  ('bend', 1),
#  ('glories', 1),
#  ('connecting', 1),
#  ('historians', 1),
#  ("'70's", 1),
#  ('viciously', 1),
#  ('griping', 1),
#  ('garry', 1),
#  ('shandling', 1),
#  ('[sade]', 1),
#  ('deceitful', 1),
#  ('idealistically', 1),
#  ('selfless', 1),
#  ('coldly', 1),
#  ('self-interested', 1),
#  ('unselfconscious', 1),
#  ('munch', 1),
#  ('invariably', 1),
#  ('cockamamie', 1),
#  ('precipitously', 1),
#  ('catastrophe', 1),
#  ('nerve-wracking', 1),
#  ('screamingly', 1),
#  ('[binoche', 1),
#  ...]

# %%
# 初始化两个token：pad和unk
vocab = ["<pad>", "<unk>"]

# 去除出现频次为1次的单词
for w, f in c.most_common():
    if f > 1:
        vocab.append(w)

# %%
print("The total size of our vocabulary is: {}".format(len(vocab)))
# Out:
# The total size of our vocabulary is: 10384

# %% [markdown]
# #### 构造映射

# %%
# 单词到编码的映射，例如machine -> 10283
word_to_token = {word: token for token, word in enumerate(vocab)}
# 编码到单词的映射，例如10283 -> machine
token_to_word = {token: word for word, token in word_to_token.items()}

# %% [markdown]
# #### 转换文本

# %%
def convert_text_to_token(sentence, word_to_token_map=word_to_token, limit_size=SENTENCE_LIMIT_SIZE):
    """
    根据单词-编码映射表将单个句子转化为token
    
    @param sentence: 句子，str类型
    @param word_to_token_map: 单词到编码的映射
    @param limit_size: 句子最大长度。超过该长度的句子进行截断，不足的句子进行pad补全
    
    return: 句子转换为token后的列表
    """
    # 获取unknown单词和pad的token
    unk_id = word_to_token_map["<unk>"]
    pad_id = word_to_token_map["<pad>"]
    
    # 对句子进行token转换，对于未在词典中出现过的词用unk的token填充
    tokens = [word_to_token_map.get(word, unk_id) for word in sentence.lower().split()]
    
    # Pad
    if len(tokens) < limit_size:
        tokens.extend([0] * (limit_size - len(tokens)))
    # Trunc
    else:
        tokens = tokens[:limit_size]
    
    return tokens

# %%
# 对pos文本处理
pos_tokens = []

for sentence in tqdm.tqdm(pos_sentences):
    tokens = convert_text_to_token(sentence)
    pos_tokens.append(tokens)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 5331/5331 [00:00<00:00, 177988.73it/s]

# %%
# 对neg文本处理
neg_tokens = []

for sentence in tqdm.tqdm(neg_sentences):
    tokens = convert_text_to_token(sentence)
    neg_tokens.append(tokens)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 5331/5331 [00:00<00:00, 178035.50it/s]

# %%
# 转化为numpy格式，方便处理
pos_tokens = np.array(pos_tokens)
neg_tokens = np.array(neg_tokens)

# %%
# 合并所有语料
total_tokens = np.concatenate((pos_tokens, neg_tokens), axis=0)

# %%
print("The shape of all tokens in our corpus: ({}, {})".format(*total_tokens.shape))
# Out:
# The shape of all tokens in our corpus: (10662, 20)

# %%
# 转化为numpy格式，方便处理
pos_targets = np.ones((pos_tokens.shape[0]))
neg_targets = np.zeros((neg_tokens.shape[0]))

# %%
# 合并所有target
total_targets = np.concatenate((pos_targets, neg_targets), axis=0).reshape(-1, 1)

# %%
print("The shape of all targets in our corpus: ({}, {})".format(*total_targets.shape))
# Out:
# The shape of all targets in our corpus: (10662, 1)

# %% [markdown]
# #### 构造词向量
# 我们使用glove预训练好的词向量来做embedding:
# * 如果当前词没有对应词向量，则用随机数产生的向量替代
# * 如果当前词为< PAD >，则用0向量代替

# %%
# 加载预训练好的glove词向量
with open("../dataset/glove.6B.300d.txt", 'r',encoding='utf-8') as f:
    words = set()
    word_to_vec = {}
    for line in f:
        line = line.strip().split()
        # 当前单词
        curr_word = line[0]
        words.add(curr_word)
        # 当前词向量
        word_to_vec[curr_word] = np.array(line[1:], dtype=np.float32)

# %%
print("The number of words which have pretrained-vectors in vocab is: {}".format(len(set(vocab)&set(words))))
print()
print("The number of words which do not have pretrained-vectors in vocab is : {}".format(len(set(vocab))-
                                                                                         len(set(vocab)&set(words))))
# Out:
# The number of words which have pretrained-vectors in vocab is: 9801
#
# The number of words which do not have pretrained-vectors in vocab is : 583

# %% [markdown]
# #### 构造词向量矩阵

# %%
VOCAB_SIZE = len(vocab)  # 10384
EMBEDDING_SIZE = 300

# %%
# 初始化词向量矩阵（这里命名为static是因为这个词向量矩阵用预训练好的填充，无需重新训练）
static_embeddings = np.zeros([VOCAB_SIZE, EMBEDDING_SIZE])

for word, token in tqdm.tqdm(word_to_token.items()):
    # 用glove词向量填充，如果没有对应的词向量，则用随机数填充
    word_vector = word_to_vec.get(word, 0.2 * np.random.random(EMBEDDING_SIZE) - 0.1)
    static_embeddings[token, :] = word_vector

# 重置PAD为0向量
pad_id = word_to_token["<pad>"]
static_embeddings[pad_id, :] = np.zeros(EMBEDDING_SIZE)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 10384/10384 [00:00<00:00, 128540.93it/s]

# %%
static_embeddings = static_embeddings.astype(np.float32)

# %% [markdown]
# ### 辅助函数

# %% [markdown]
# #### 分割train和test

# %%
def split_train_test(x, y, train_ratio=0.8, shuffle=True):
    """
    分割train和test
    
    @param x: 输入特征
    @param y: 目标
    @param train_ratio: 训练样本比例
    @param shuffle: 是否shuffle
    """
    assert x.shape[0] == y.shape[0],  print("error shape!")
    
    if shuffle:
        # shuffle
        shuffled_index = np.random.permutation(range(x.shape[0]))
        x = x[shuffled_index]
        y = y[shuffled_index]
    
    # 分离train和test
    train_size = int(x.shape[0] * train_ratio)
    x_train = x[:train_size]
    x_test = x[train_size:]
    y_train = y[:train_size]
    y_test = y[train_size:]
    
    return x_train, x_test, y_train, y_test

# %%
# 划分train和test
x_train, x_test, y_train, y_test = split_train_test(total_tokens, total_targets)

# %% [markdown]
# #### get_batch函数

# %%
# 定义神经网络超参数
HIDDEN_SIZE = 512
LEARNING_RATE = 0.001
EPOCHES = 50
BATCH_SIZE = 256

# %%
def get_batch(x, y, batch_size=BATCH_SIZE, shuffle=True):
    assert x.shape[0] == y.shape[0], print("error shape!")
    # shuffle
    if shuffle:
        shuffled_index = np.random.permutation(range(x.shape[0]))

        x = x[shuffled_index]
        y = y[shuffled_index]
    
    # 统计共几个完整的batch
    n_batches = int(x.shape[0] / batch_size)
    
    for i in range(n_batches - 1):
        x_batch = x[i*batch_size: (i+1)*batch_size]
        y_batch = y[i*batch_size: (i+1)*batch_size]
    
        yield x_batch, y_batch

# %% [markdown]
# ### DNN模型

# %%
# 清空图
tf.reset_default_graph()

# %%
with tf.name_scope("dnn"):
    # 输入及输出tensor
    with tf.name_scope("placeholders"):
        inputs = tf.placeholder(dtype=tf.int32, shape=(None, SENTENCE_LIMIT_SIZE), name="inputs")
        targets = tf.placeholder(dtype=tf.float32, shape=(None, 1), name="targets")
    
    # embeddings
    with tf.name_scope("embeddings"):
        # 用pre-trained词向量来作为embedding层
        embedding_matrix = tf.Variable(initial_value=static_embeddings, trainable=False, name="embedding_matrix")
        embed = tf.nn.embedding_lookup(embedding_matrix, inputs, name="embed")
        # 相加词向量得到句子向量
        sum_embed = tf.reduce_sum(embed, axis=1, name="sum_embed")
        
    # model
    with tf.name_scope("model"):
        # 隐层权重
        W1 = tf.Variable(tf.random_normal(shape=(EMBEDDING_SIZE, HIDDEN_SIZE), stddev=0.1), name="W1")
        b1 = tf.Variable(tf.zeros(shape=(HIDDEN_SIZE), name="b1"))
        
        # 输出层权重
        W2 = tf.Variable(tf.random_normal(shape=(HIDDEN_SIZE, 1), stddev=0.1), name="W2")
        b2 = tf.Variable(tf.zeros(shape=(1), name="b2"))
        
        # 结果
        z1 = tf.add(tf.matmul(sum_embed, W1), b1)
        a1 = tf.nn.relu(z1)
        
        logits = tf.add(tf.matmul(a1, W2), b2)
        outputs = tf.nn.sigmoid(logits, name="outputs")
    
    # loss
    with tf.name_scope("loss"):
        loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=targets, logits=logits))
    
    # optimizer
    with tf.name_scope("optimizer"):
        optimizer = tf.train.AdamOptimizer(LEARNING_RATE).minimize(loss)
        
    # evaluation
    with tf.name_scope("evaluation"):
        correct_preds = tf.equal(tf.cast(tf.greater(outputs, 0.5), tf.float32), targets)
        accuracy = tf.reduce_sum(tf.reduce_sum(tf.cast(correct_preds, tf.float32), axis=1))

# %% [markdown]
# #### 训练模型

# %%
# 存储准确率
dnn_train_accuracy = []
dnn_test_accuracy = []

# %%
saver = tf.train.Saver()

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    writer = tf.summary.FileWriter("../dataset/graphs/dnn", tf.get_default_graph())
    
    n_batches = int(x_train.shape[0] / BATCH_SIZE)
    
    for epoch in range(EPOCHES):
        total_loss = 0
        
        for x_batch, y_batch in get_batch(x_train, y_train):
            _, batch_loss = sess.run([optimizer, loss],
                                     feed_dict={inputs: x_batch, targets: y_batch})
            
            total_loss += batch_loss
        
        # 在train上准确率
        train_corrects = sess.run(accuracy, feed_dict={inputs: x_train, targets: y_train})
        train_acc = train_corrects / x_train.shape[0]
        dnn_train_accuracy.append(train_acc)
        
        # 在test上准确率
        test_corrects = sess.run(accuracy, feed_dict={inputs: x_test, targets: y_test})
        test_acc = test_corrects / x_test.shape[0]
        dnn_test_accuracy.append(test_acc)
        
        print("Epoch: {}, Train loss: {:.4f}, Train accuracy: {:.4f}, Test accuracy: {:.4f}".format(epoch + 1, 
                                                                                                    total_loss/n_batches,
                                                                                                    train_acc,
                                                                                                    test_acc))
    # 存储模型
    saver.save(sess, "../dataset/checkpoints/dnn")
    writer.close()
# Out:
# Epoch: 1, Train loss: 1.6486, Train accuracy: 0.6752, Test accuracy: 0.6634
# Epoch: 2, Train loss: 0.7149, Train accuracy: 0.7055, Test accuracy: 0.6784
# Epoch: 3, Train loss: 0.5811, Train accuracy: 0.7389, Test accuracy: 0.6934
# Epoch: 4, Train loss: 0.5405, Train accuracy: 0.7596, Test accuracy: 0.7164
# Epoch: 5, Train loss: 0.4851, Train accuracy: 0.7823, Test accuracy: 0.7257
# Epoch: 6, Train loss: 0.4694, Train accuracy: 0.7892, Test accuracy: 0.7084
# Epoch: 7, Train loss: 0.4413, Train accuracy: 0.8024, Test accuracy: 0.7159
# Epoch: 8, Train loss: 0.4270, Train accuracy: 0.8089, Test accuracy: 0.7178
# Epoch: 9, Train loss: 0.3906, Train accuracy: 0.8330, Test accuracy: 0.7257
# Epoch: 10, Train loss: 0.3684, Train accuracy: 0.8465, Test accuracy: 0.7304
# Epoch: 11, Train loss: 0.3469, Train accuracy: 0.8595, Test accuracy: 0.7309
# Epoch: 12, Train loss: 0.3245, Train accuracy: 0.8634, Test accuracy: 0.7075
# Epoch: 13, Train loss: 0.3184, Train accuracy: 0.8724, Test accuracy: 0.7211
# Epoch: 14, Train loss: 0.2947, Train accuracy: 0.8789, Test accuracy: 0.7234
# Epoch: 15, Train loss: 0.2729, Train accuracy: 0.9122, Test accuracy: 0.7234
# Epoch: 16, Train loss: 0.2509, Train accuracy: 0.9190, Test accuracy: 0.7384
# Epoch: 17, Train loss: 0.2413, Train accuracy: 0.8601, Test accuracy: 0.7154
# Epoch: 18, Train loss: 0.2206, Train accuracy: 0.9486, Test accuracy: 0.7356
# Epoch: 19, Train loss: 0.1966, Train accuracy: 0.9502, Test accuracy: 0.7304
# Epoch: 20, Train loss: 0.1825, Train accuracy: 0.9550, Test accuracy: 0.7178
# Epoch: 21, Train loss: 0.1632, Train accuracy: 0.9706, Test accuracy: 0.7286
# Epoch: 22, Train loss: 0.1481, Train accuracy: 0.9381, Test accuracy: 0.7192
# Epoch: 23, Train loss: 0.1408, Train accuracy: 0.9742, Test accuracy: 0.7346
# Epoch: 24, Train loss: 0.1208, Train accuracy: 0.9859, Test accuracy: 0.7332
# Epoch: 25, Train loss: 0.1157, Train accuracy: 0.9851, Test accuracy: 0.7314
# Epoch: 26, Train loss: 0.1057, Train accuracy: 0.9900, Test accuracy: 0.7323
# Epoch: 27, Train loss: 0.0976, Train accuracy: 0.9909, Test accuracy: 0.7271
# Epoch: 28, Train loss: 0.0895, Train accuracy: 0.9941, Test accuracy: 0.7384
# Epoch: 29, Train loss: 0.0869, Train accuracy: 0.9957, Test accuracy: 0.7375
# Epoch: 30, Train loss: 0.0725, Train accuracy: 0.9938, Test accuracy: 0.7356
# Epoch: 31, Train loss: 0.0663, Train accuracy: 0.9968, Test accuracy: 0.7356
# Epoch: 32, Train loss: 0.0575, Train accuracy: 0.9971, Test accuracy: 0.7314
# Epoch: 33, Train loss: 0.0528, Train accuracy: 0.9973, Test accuracy: 0.7393
# Epoch: 34, Train loss: 0.0488, Train accuracy: 0.9991, Test accuracy: 0.7365
# Epoch: 35, Train loss: 0.0439, Train accuracy: 0.9988, Test accuracy: 0.7286
# Epoch: 36, Train loss: 0.0416, Train accuracy: 0.9993, Test accuracy: 0.7389
# Epoch: 37, Train loss: 0.0376, Train accuracy: 0.9989, Test accuracy: 0.7314
# Epoch: 38, Train loss: 0.0342, Train accuracy: 0.9993, Test accuracy: 0.7346
# Epoch: 39, Train loss: 0.0308, Train accuracy: 0.9995, Test accuracy: 0.7290
# Epoch: 40, Train loss: 0.0287, Train accuracy: 0.9996, Test accuracy: 0.7361
# Epoch: 41, Train loss: 0.0264, Train accuracy: 0.9999, Test accuracy: 0.7309
# Epoch: 42, Train loss: 0.0237, Train accuracy: 0.9999, Test accuracy: 0.7351
# Epoch: 43, Train loss: 0.0224, Train accuracy: 0.9999, Test accuracy: 0.7346
# Epoch: 44, Train loss: 0.0211, Train accuracy: 1.0000, Test accuracy: 0.7309
# Epoch: 45, Train loss: 0.0201, Train accuracy: 0.9999, Test accuracy: 0.7365
# Epoch: 46, Train loss: 0.0186, Train accuracy: 0.9999, Test accuracy: 0.7370
# Epoch: 47, Train loss: 0.0168, Train accuracy: 1.0000, Test accuracy: 0.7337
# Epoch: 48, Train loss: 0.0160, Train accuracy: 1.0000, Test accuracy: 0.7328
# Epoch: 49, Train loss: 0.0148, Train accuracy: 1.0000, Test accuracy: 0.7342
# Epoch: 50, Train loss: 0.0141, Train accuracy: 1.0000, Test accuracy: 0.7332

# %%
plt.plot(dnn_train_accuracy)
plt.plot(dnn_test_accuracy)
plt.ylim(ymin=0.5, ymax=1.01)
plt.title("The accuracy of DNN model")
plt.legend(["train", "test"])

# %% [markdown]
# #### 预测模型

# %%
# 在test上的准确率
with tf.Session() as sess:
    saver.restore(sess, "../dataset/checkpoints/dnn")
    
    total_correct = 0
    acc = sess.run(accuracy,
                    feed_dict={inputs: x_test, 
                                targets: y_test})
    total_correct += acc
    print("The DNN model accuracy on test set: {:.2f}%".format(100* total_correct / x_test.shape[0]))
# Out:
# INFO:tensorflow:Restoring parameters from ../dataset/checkpoints/dnn
# The DNN model accuracy on test set: 73.32%

# %% [markdown]
# ### RNN模型

# %%
# 清空图
tf.reset_default_graph()

# %%
# 定义网络超参数
HIDDEN_SIZE = 512
LEARNING_RATE = 0.001
KEEP_PROB = 0.5
EPOCHES = 50
BATCH_SIZE = 256

# %%
with tf.name_scope("rnn"):
    # placeholders
    with tf.name_scope("placeholders"):
        inputs = tf.placeholder(dtype=tf.int32, shape=(None, 20), name="inputs")
        targets = tf.placeholder(dtype=tf.float32, shape=(None, 1), name="targets")
    
    # embeddings
    with tf.name_scope("embeddings"):
        embedding_matrix = tf.Variable(initial_value=static_embeddings, trainable=False, name="embedding_matrix")
        embed = tf.nn.embedding_lookup(embedding_matrix, inputs, name="embed")
    
    # model
    with tf.name_scope("model"):
        # 构造lstm单元
        lstm = tf.contrib.rnn.LSTMCell(HIDDEN_SIZE, initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=123))
        # 添加dropout
        drop_lstm = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=KEEP_PROB)
        _, lstm_state = tf.nn.dynamic_rnn(drop_lstm, embed, dtype=tf.float32)
        
        # 输出层权重
        W = tf.Variable(tf.truncated_normal((HIDDEN_SIZE, 1), mean=0.0, stddev=0.1), name="W")
        b = tf.Variable(tf.zeros(1), name="b")
        
        logits = tf.add(tf.matmul(lstm_state.h, W), b)
        outputs = tf.nn.sigmoid(logits, name="outputs")
        
        loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=targets, logits=logits))
    
    # optimizer
    with tf.name_scope("optimizer"):
        optimizer = tf.train.AdamOptimizer(LEARNING_RATE).minimize(loss)
    
    # evaluation
    with tf.name_scope("evaluation"):
        correct_preds = tf.equal(tf.cast(tf.greater(outputs, 0.5), tf.float32), targets)
        accuracy = tf.reduce_sum(tf.reduce_sum(tf.cast(correct_preds, tf.float32), axis=1))

# %% [markdown]
# #### 训练模型

# %%
# 存储准确率
rnn_train_accuracy = []
rnn_test_accuracy = []

# %%
saver = tf.train.Saver()

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    writer = tf.summary.FileWriter("../dataset/graphs/rnn", tf.get_default_graph())
    n_batches = int(x_train.shape[0] / BATCH_SIZE)
    
    for epoch in range(EPOCHES):
        total_loss = 0
        for x_batch, y_batch in get_batch(x_train, y_train):
            _, l = sess.run([optimizer, loss],
                            feed_dict={inputs: x_batch, 
                                       targets: y_batch})
            total_loss += l
        
        train_corrects = sess.run(accuracy, feed_dict={inputs: x_train, targets: y_train})
        train_acc = train_corrects / x_train.shape[0]
        rnn_train_accuracy.append(train_acc)

        test_corrects = sess.run(accuracy, feed_dict={inputs: x_test, targets: y_test})
        test_acc = test_corrects / x_test.shape[0]
        rnn_test_accuracy.append(test_acc)

        
        print("Training epoch: {}, Train loss: {:.4f}, Train accuracy: {:.4f}, Test accuracy: {:.4f}".format(epoch + 1, 
                                                                                                             total_loss / n_batches,
                                                                                                             train_acc,
                                                                                                             test_acc))
    
    saver.save(sess, "../dataset/checkpoints/rnn")
    writer.close()
# Out:
# Training epoch: 1, Train loss: 0.6310, Train accuracy: 0.7240, Test accuracy: 0.7046
# Training epoch: 2, Train loss: 0.4956, Train accuracy: 0.7756, Test accuracy: 0.7304
# Training epoch: 3, Train loss: 0.4692, Train accuracy: 0.7804, Test accuracy: 0.7262
# Training epoch: 4, Train loss: 0.4326, Train accuracy: 0.8214, Test accuracy: 0.7543
# Training epoch: 5, Train loss: 0.3848, Train accuracy: 0.8550, Test accuracy: 0.7398
# Training epoch: 6, Train loss: 0.3427, Train accuracy: 0.8430, Test accuracy: 0.7314
# Training epoch: 7, Train loss: 0.2910, Train accuracy: 0.9130, Test accuracy: 0.7492
# Training epoch: 8, Train loss: 0.2284, Train accuracy: 0.9343, Test accuracy: 0.7454
# Training epoch: 9, Train loss: 0.1852, Train accuracy: 0.9538, Test accuracy: 0.7445
# Training epoch: 10, Train loss: 0.1272, Train accuracy: 0.9780, Test accuracy: 0.7361
# Training epoch: 11, Train loss: 0.0924, Train accuracy: 0.9805, Test accuracy: 0.7445
# Training epoch: 12, Train loss: 0.0672, Train accuracy: 0.9873, Test accuracy: 0.7365
# Training epoch: 13, Train loss: 0.0712, Train accuracy: 0.9808, Test accuracy: 0.7159
# Training epoch: 14, Train loss: 0.0557, Train accuracy: 0.9926, Test accuracy: 0.7407
# Training epoch: 15, Train loss: 0.0520, Train accuracy: 0.9804, Test accuracy: 0.7361
# Training epoch: 16, Train loss: 0.0564, Train accuracy: 0.9933, Test accuracy: 0.7323
# Training epoch: 17, Train loss: 0.0408, Train accuracy: 0.9926, Test accuracy: 0.7356
# Training epoch: 18, Train loss: 0.0246, Train accuracy: 0.9978, Test accuracy: 0.7370
# Training epoch: 19, Train loss: 0.0214, Train accuracy: 0.9953, Test accuracy: 0.7201
# Training epoch: 20, Train loss: 0.0177, Train accuracy: 0.9974, Test accuracy: 0.7295
# Training epoch: 21, Train loss: 0.0125, Train accuracy: 0.9967, Test accuracy: 0.7328
# Training epoch: 22, Train loss: 0.0218, Train accuracy: 0.9968, Test accuracy: 0.7482
# Training epoch: 23, Train loss: 0.0085, Train accuracy: 0.9988, Test accuracy: 0.7257
# Training epoch: 24, Train loss: 0.0189, Train accuracy: 0.9945, Test accuracy: 0.7225
# Training epoch: 25, Train loss: 0.0266, Train accuracy: 0.9954, Test accuracy: 0.7304
# Training epoch: 26, Train loss: 0.0243, Train accuracy: 0.9978, Test accuracy: 0.7365
# Training epoch: 27, Train loss: 0.0136, Train accuracy: 0.9966, Test accuracy: 0.7393
# Training epoch: 28, Train loss: 0.0137, Train accuracy: 0.9968, Test accuracy: 0.7262
# Training epoch: 29, Train loss: 0.0195, Train accuracy: 0.9979, Test accuracy: 0.7346
# Training epoch: 30, Train loss: 0.0127, Train accuracy: 0.9982, Test accuracy: 0.7309
# Training epoch: 31, Train loss: 0.0046, Train accuracy: 0.9986, Test accuracy: 0.7511
# Training epoch: 32, Train loss: 0.0114, Train accuracy: 0.9964, Test accuracy: 0.7426
# Training epoch: 33, Train loss: 0.0109, Train accuracy: 0.9981, Test accuracy: 0.7417
# Training epoch: 34, Train loss: 0.0095, Train accuracy: 0.9965, Test accuracy: 0.7412
# Training epoch: 35, Train loss: 0.0115, Train accuracy: 0.9984, Test accuracy: 0.7440
# Training epoch: 36, Train loss: 0.0082, Train accuracy: 0.9984, Test accuracy: 0.7454
# Training epoch: 37, Train loss: 0.0081, Train accuracy: 0.9964, Test accuracy: 0.7267
# Training epoch: 38, Train loss: 0.0083, Train accuracy: 0.9986, Test accuracy: 0.7403
# Training epoch: 39, Train loss: 0.0202, Train accuracy: 0.9927, Test accuracy: 0.7318
# Training epoch: 40, Train loss: 0.0193, Train accuracy: 0.9979, Test accuracy: 0.7426
# Training epoch: 41, Train loss: 0.0114, Train accuracy: 0.9985, Test accuracy: 0.7375
# Training epoch: 42, Train loss: 0.0151, Train accuracy: 0.9962, Test accuracy: 0.7450
# Training epoch: 43, Train loss: 0.0180, Train accuracy: 0.9965, Test accuracy: 0.7450
# Training epoch: 44, Train loss: 0.0109, Train accuracy: 0.9994, Test accuracy: 0.7342
# Training epoch: 45, Train loss: 0.0072, Train accuracy: 0.9991, Test accuracy: 0.7440
# Training epoch: 46, Train loss: 0.0065, Train accuracy: 0.9970, Test accuracy: 0.7318
# Training epoch: 47, Train loss: 0.0110, Train accuracy: 0.9989, Test accuracy: 0.7243
# Training epoch: 48, Train loss: 0.0060, Train accuracy: 0.9994, Test accuracy: 0.7361
# Training epoch: 49, Train loss: 0.0097, Train accuracy: 0.9979, Test accuracy: 0.7346
# Training epoch: 50, Train loss: 0.0034, Train accuracy: 0.9996, Test accuracy: 0.7389

# %%
plt.plot(rnn_train_accuracy)
plt.plot(rnn_test_accuracy)
plt.ylim(ymin=0.5, ymax=1.01)
plt.title("The accuracy of LSTM model")
plt.legend(["train", "test"])

# %% [markdown]
# #### 预测模型

# %%
# 在test上的准确率
with tf.Session() as sess:
    saver.restore(sess, "../dataset/checkpoints/rnn")
    
    total_correct = sess.run(accuracy,
                             feed_dict={inputs: x_test, targets: y_test})

    print("The LSTM model accuracy on test set: {:.2f}%".format(100* total_correct / x_test.shape[0]))
# Out:
# INFO:tensorflow:Restoring parameters from ../dataset/checkpoints/rnn
# The LSTM model accuracy on test set: 73.89%

# %% [markdown]
# ### CNN模型

# %%
# 清空图
tf.reset_default_graph()

# %%
# 我在这里定义了5种filter，每种100个
filters_size = [2, 3, 4, 5, 6]
num_filters = 100
# 超参数
BATCH_SIZE = 256
EPOCHES = 50
LEARNING_RATE = 0.001
L2_LAMBDA = 10
KEEP_PROB = 0.8

# %% [markdown]
# #### 构建模型图

# %%
with tf.name_scope("cnn"):
    with tf.name_scope("placeholders"):
        inputs = tf.placeholder(
            dtype=tf.int32, shape=(None, 20), name="inputs")
        targets = tf.placeholder(
            dtype=tf.float32, shape=(None, 1), name="targets")

    # embeddings
    with tf.name_scope("embeddings"):
        embedding_matrix = tf.Variable(
            initial_value=static_embeddings, trainable=False, name="embedding_matrix")
        embed = tf.nn.embedding_lookup(embedding_matrix, inputs, name="embed")
        # 添加channel维度
        embed_expanded = tf.expand_dims(embed, -1, name="embed_expand")

    # 用来存储max-pooling的结果
    pooled_outputs = []

    # 迭代多个filter
    for i, filter_size in enumerate(filters_size):
        with tf.name_scope("conv_maxpool_%s" % filter_size):
            filter_shape = [filter_size, EMBEDDING_SIZE, 1, num_filters]
            W = tf.Variable(tf.truncated_normal(
                filter_shape, mean=0.0, stddev=0.1), name="W")
            b = tf.Variable(tf.zeros(num_filters), name="b")

            conv = tf.nn.conv2d(input=embed_expanded,
                                filter=W,
                                strides=[1, 1, 1, 1],
                                padding="VALID",
                                name="conv")

            # 激活
            a = tf.nn.relu(tf.nn.bias_add(conv, b), name="activations")
            # 池化
            max_pooling = tf.nn.max_pool(value=a,
                                         ksize=[1, SENTENCE_LIMIT_SIZE -
                                                filter_size + 1, 1, 1],
                                         strides=[1, 1, 1, 1],
                                         padding="VALID",
                                         name="max_pooling")
            pooled_outputs.append(max_pooling)

    # 统计所有的filter
    total_filters = num_filters * len(filters_size)
    total_pool = tf.concat(pooled_outputs, 3)
    flattend_pool = tf.reshape(total_pool, (-1, total_filters))

    # dropout
    with tf.name_scope("dropout"):
        dropout = tf.nn.dropout(flattend_pool, KEEP_PROB)

    # output
    with tf.name_scope("output"):
        W = tf.get_variable("W", shape=(total_filters, 1),
                            initializer=tf.contrib.layers.xavier_initializer())
        b = tf.Variable(tf.zeros(1), name="b")

        logits = tf.add(tf.matmul(dropout, W), b)
        predictions = tf.nn.sigmoid(logits, name="predictions")

    # loss
    with tf.name_scope("loss"):
        loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(
            labels=targets, logits=logits))
        loss = loss + L2_LAMBDA * tf.nn.l2_loss(W)
        optimizer = tf.train.AdamOptimizer(LEARNING_RATE).minimize(loss)

    # evaluation
    with tf.name_scope("evaluation"):
        correct_preds = tf.equal(
            tf.cast(tf.greater(predictions, 0.5), tf.float32), targets)
        accuracy = tf.reduce_sum(tf.reduce_sum(
            tf.cast(correct_preds, tf.float32), axis=1))

# %% [markdown]
# #### 训练模型

# %%
# 存储准确率
cnn_train_accuracy = []
cnn_test_accuracy = []

# %%
saver = tf.train.Saver()

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    writer = tf.summary.FileWriter("../dataset/graphs/cnn", tf.get_default_graph())
    n_batches = int(x_train.shape[0] / BATCH_SIZE)
    
    for epoch in range(EPOCHES):
        total_loss = 0
        for x_batch, y_batch in get_batch(x_train, y_train):
            _, l = sess.run([optimizer, loss],
                            feed_dict={inputs: x_batch, 
                                       targets: y_batch})
            total_loss += l
        
        train_corrects = sess.run(accuracy, feed_dict={inputs: x_train, targets: y_train})
        train_acc = train_corrects / x_train.shape[0]
        cnn_train_accuracy.append(train_acc)
        
        test_corrects = sess.run(accuracy, feed_dict={inputs: x_test, targets: y_test})
        test_acc = test_corrects / x_test.shape[0]
        cnn_test_accuracy.append(test_acc)
        
        print("Training epoch: {}, Training loss: {:.4f}, Train accuracy: {:.4f}, Test accuracy: {:.4f}".format(epoch + 1, 
                                                                                                                total_loss / n_batches,
                                                                                                                train_acc,
                                                                                                               test_acc))
    
    saver.save(sess, "../dataset/checkpoints/cnn")
    writer.close()
# Out:
# Training epoch: 1, Training loss: 7.8767, Train accuracy: 0.6872, Test accuracy: 0.6629
# Training epoch: 2, Training loss: 3.2927, Train accuracy: 0.7378, Test accuracy: 0.6812
# Training epoch: 3, Training loss: 1.4621, Train accuracy: 0.7518, Test accuracy: 0.6953
# Training epoch: 4, Training loss: 0.8544, Train accuracy: 0.7649, Test accuracy: 0.7159
# Training epoch: 5, Training loss: 0.6827, Train accuracy: 0.7669, Test accuracy: 0.7089
# Training epoch: 6, Training loss: 0.6334, Train accuracy: 0.7404, Test accuracy: 0.7089
# Training epoch: 7, Training loss: 0.6138, Train accuracy: 0.7630, Test accuracy: 0.7192
# Training epoch: 8, Training loss: 0.5960, Train accuracy: 0.7666, Test accuracy: 0.7403
# Training epoch: 9, Training loss: 0.5825, Train accuracy: 0.7690, Test accuracy: 0.7431
# Training epoch: 10, Training loss: 0.5711, Train accuracy: 0.7705, Test accuracy: 0.7440
# Training epoch: 11, Training loss: 0.5621, Train accuracy: 0.7736, Test accuracy: 0.7370
# Training epoch: 12, Training loss: 0.5521, Train accuracy: 0.7650, Test accuracy: 0.7361
# Training epoch: 13, Training loss: 0.5487, Train accuracy: 0.7804, Test accuracy: 0.7421
# Training epoch: 14, Training loss: 0.5381, Train accuracy: 0.7851, Test accuracy: 0.7450
# Training epoch: 15, Training loss: 0.5332, Train accuracy: 0.7846, Test accuracy: 0.7501
# Training epoch: 16, Training loss: 0.5293, Train accuracy: 0.7936, Test accuracy: 0.7529
# Training epoch: 17, Training loss: 0.5230, Train accuracy: 0.7684, Test accuracy: 0.7276
# Training epoch: 18, Training loss: 0.5220, Train accuracy: 0.7778, Test accuracy: 0.7370
# Training epoch: 19, Training loss: 0.5168, Train accuracy: 0.7878, Test accuracy: 0.7482
# Training epoch: 20, Training loss: 0.5087, Train accuracy: 0.7952, Test accuracy: 0.7454
# Training epoch: 21, Training loss: 0.5051, Train accuracy: 0.8041, Test accuracy: 0.7567
# Training epoch: 22, Training loss: 0.4987, Train accuracy: 0.7988, Test accuracy: 0.7525
# Training epoch: 23, Training loss: 0.4966, Train accuracy: 0.8082, Test accuracy: 0.7567
# Training epoch: 24, Training loss: 0.4906, Train accuracy: 0.8163, Test accuracy: 0.7647
# Training epoch: 25, Training loss: 0.4880, Train accuracy: 0.8001, Test accuracy: 0.7482
# Training epoch: 26, Training loss: 0.4853, Train accuracy: 0.8133, Test accuracy: 0.7656
# Training epoch: 27, Training loss: 0.4822, Train accuracy: 0.8223, Test accuracy: 0.7632
# Training epoch: 28, Training loss: 0.4814, Train accuracy: 0.8057, Test accuracy: 0.7384
# Training epoch: 29, Training loss: 0.4736, Train accuracy: 0.8174, Test accuracy: 0.7548
# Training epoch: 30, Training loss: 0.4735, Train accuracy: 0.8259, Test accuracy: 0.7618
# Training epoch: 31, Training loss: 0.4682, Train accuracy: 0.8318, Test accuracy: 0.7642
# Training epoch: 32, Training loss: 0.4653, Train accuracy: 0.8298, Test accuracy: 0.7590
# Training epoch: 33, Training loss: 0.4601, Train accuracy: 0.8380, Test accuracy: 0.7665
# Training epoch: 34, Training loss: 0.4576, Train accuracy: 0.8321, Test accuracy: 0.7576
# Training epoch: 35, Training loss: 0.4549, Train accuracy: 0.8412, Test accuracy: 0.7637
# Training epoch: 36, Training loss: 0.4521, Train accuracy: 0.8435, Test accuracy: 0.7656
# Training epoch: 37, Training loss: 0.4483, Train accuracy: 0.8422, Test accuracy: 0.7637
# Training epoch: 38, Training loss: 0.4459, Train accuracy: 0.8451, Test accuracy: 0.7637
# Training epoch: 39, Training loss: 0.4425, Train accuracy: 0.8502, Test accuracy: 0.7642
# Training epoch: 40, Training loss: 0.4379, Train accuracy: 0.8529, Test accuracy: 0.7618
# Training epoch: 41, Training loss: 0.4356, Train accuracy: 0.8559, Test accuracy: 0.7675
# Training epoch: 42, Training loss: 0.4358, Train accuracy: 0.8597, Test accuracy: 0.7609
# Training epoch: 43, Training loss: 0.4308, Train accuracy: 0.8578, Test accuracy: 0.7647
# Training epoch: 44, Training loss: 0.4281, Train accuracy: 0.8631, Test accuracy: 0.7614
# Training epoch: 45, Training loss: 0.4254, Train accuracy: 0.8621, Test accuracy: 0.7609
# Training epoch: 46, Training loss: 0.4236, Train accuracy: 0.8538, Test accuracy: 0.7600
# Training epoch: 47, Training loss: 0.4215, Train accuracy: 0.8663, Test accuracy: 0.7637
# Training epoch: 48, Training loss: 0.4167, Train accuracy: 0.8711, Test accuracy: 0.7590
# Training epoch: 49, Training loss: 0.4194, Train accuracy: 0.8736, Test accuracy: 0.7651
# Training epoch: 50, Training loss: 0.4120, Train accuracy: 0.8762, Test accuracy: 0.7722

# %%
plt.plot(cnn_train_accuracy)
plt.plot(cnn_test_accuracy)
plt.ylim(ymin=0.5, ymax=1.01)
plt.title("The accuracy of CNN model")
plt.legend(["train", "test"])

# %% [markdown]
# #### 预测模型

# %%
# 在test上的准确率
with tf.Session() as sess:
    saver.restore(sess, "../dataset/checkpoints/cnn")
    
    total_correct = sess.run(accuracy,
                             feed_dict={inputs: x_test, targets: y_test})

    print("The LSTM model accuracy on test set: {:.2f}%".format(100 * total_correct / x_test.shape[0]))
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 762
# INFO:tensorflow:Restoring parameters from ../dataset/checkpoints/cnn
# The LSTM model accuracy on test set: 76.70%

# %% [markdown]
# ### CNN multi-channel

# %% [markdown]
# #### 构建模型图

# %%
# 清空图
tf.reset_default_graph()

# %%
# 我在这里定义了5种filter，每种100个
filters_size = [2, 3, 4, 5, 6]
num_filters = 100
# 超参数
BATCH_SIZE = 256
EPOCHES = 8
LEARNING_RATE = 0.001
L2_LAMBDA = 10
KEEP_PROB = 0.8

# %%
with tf.name_scope("cnn_multichannels"):
    with tf.name_scope("placeholders"):
        inputs = tf.placeholder(dtype=tf.int32, shape=(None, 20), name="inputs")
        targets = tf.placeholder(dtype=tf.float32, shape=(None, 1), name="targets")
    # embeddings
    with tf.name_scope("embeddings"):
        # static embeddings
        static_embedding_matrix = tf.Variable(initial_value=static_embeddings, 
                                              trainable=False, 
                                              name="static_embedding_matrix")
        static_embed = tf.nn.embedding_lookup(static_embedding_matrix, inputs, name="static_embed")
        static_embed_expanded = tf.expand_dims(static_embed, -1, name="static_embed_expand")
        
        # non-static embeddings
        dynamic_embedding_matrix = tf.Variable(tf.random_normal(shape=(VOCAB_SIZE, EMBEDDING_SIZE), stddev=0.1), 
                                               trainable=True, 
                                               name="dynamic_embedding_matrix")
        dynamic_embed = tf.nn.embedding_lookup(dynamic_embedding_matrix, inputs, name="dynamic_embed")
        dynamic_embed_expanded = tf.expand_dims(dynamic_embed, -1, name="dynamic_embed_expand")
        
        # stack
        embed_expanded = tf.concat((static_embed_expanded, dynamic_embed_expanded), axis=-1, name="embed_expanded")
    
    pooled_outputs = []

    # 迭代多个filter
    for i, filter_size in enumerate(filters_size):
        with tf.name_scope("conv_maxpool_%s" % filter_size):
            # 注意这里filter的channel要指定为2
            filter_shape = [filter_size, EMBEDDING_SIZE, 2, num_filters]
            W = tf.Variable(tf.truncated_normal(filter_shape, mean=0.0, stddev=0.1), name="W")
            b = tf.Variable(tf.zeros(num_filters), name="b")

            conv = tf.nn.conv2d(input=embed_expanded, 
                                 filter=W, 
                                 strides=[1, 1, 1, 1], 
                                 padding="VALID",
                                 name="conv")

            # 激活
            a = tf.nn.relu(tf.nn.bias_add(conv, b), name="activations")
            # 池化
            max_pooling = tf.nn.max_pool(value=a, 
                                    ksize=[1, SENTENCE_LIMIT_SIZE - filter_size + 1, 1, 1],
                                    strides=[1, 1, 1, 1],
                                   padding="VALID",
                                   name="max_pooling")
            pooled_outputs.append(max_pooling)
        
    total_filters = num_filters * len(filters_size)
    total_pool = tf.concat(pooled_outputs, 3)
    flattend_pool = tf.reshape(total_pool, (-1, total_filters))
    
    with tf.name_scope("dropout"):
        dropout = tf.nn.dropout(flattend_pool, KEEP_PROB)
    
    with tf.name_scope("output"):
        W = tf.get_variable("W", shape=(total_filters, 1), initializer=tf.contrib.layers.xavier_initializer())
        b = tf.Variable(tf.zeros(1), name="b")
        
        logits = tf.add(tf.matmul(dropout, W), b)
        predictions = tf.nn.sigmoid(logits, name="predictions")
    
    with tf.name_scope("loss"):
        loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=targets, logits=logits))
        loss = loss + L2_LAMBDA * tf.nn.l2_loss(W)
        optimizer = tf.train.AdamOptimizer(LEARNING_RATE).minimize(loss)
    
    with tf.name_scope("evaluation"):
        correct_preds = tf.equal(tf.cast(tf.greater(predictions, 0.5), tf.float32), targets)
        accuracy = tf.reduce_sum(tf.reduce_sum(tf.cast(correct_preds, tf.float32), axis=1))

# %% [markdown]
# #### 训练模型

# %%
multi_cnn_train_accuracy = []
multi_cnn_test_accuracy = []

# %%
saver = tf.train.Saver()

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    writer = tf.summary.FileWriter("../dataset/graphs/multi_cnn", tf.get_default_graph())
    n_batches = int(x_train.shape[0] / BATCH_SIZE)
    
    for epoch in range(EPOCHES):
        total_loss = 0
        for x_batch, y_batch in get_batch(x_train, y_train):
            _, l = sess.run([optimizer, loss],
                            feed_dict={inputs: x_batch, 
                                       targets: y_batch})
            total_loss += l
        
        train_corrects = sess.run(accuracy, feed_dict={inputs: x_train, targets: y_train})
        train_acc = train_corrects / x_train.shape[0]
        multi_cnn_train_accuracy.append(train_acc)
        
        test_corrects = sess.run(accuracy, feed_dict={inputs: x_test, targets: y_test})
        test_acc = test_corrects / x_test.shape[0]
        multi_cnn_test_accuracy.append(test_acc)
        
        print("Training epoch: {}, Training loss: {:.4f}, Train accuracy: {:.4f}, Test accuracy: {:.4f}".format(epoch + 1, 
                                                                                                                total_loss / n_batches,
                                                                                                                train_acc,
                                                                                                                test_acc))
    
    saver.save(sess, "../dataset/checkpoints/multi_cnn")
    writer.close()
# Out:
# Training epoch: 1, Training loss: 7.4564, Train accuracy: 0.7553, Test accuracy: 0.6770
# Training epoch: 2, Training loss: 2.9248, Train accuracy: 0.8318, Test accuracy: 0.7051
# Training epoch: 3, Training loss: 1.2656, Train accuracy: 0.8504, Test accuracy: 0.7225
# Training epoch: 4, Training loss: 0.7569, Train accuracy: 0.8355, Test accuracy: 0.7234
# Training epoch: 5, Training loss: 0.6208, Train accuracy: 0.8459, Test accuracy: 0.7492
# Training epoch: 6, Training loss: 0.5720, Train accuracy: 0.8318, Test accuracy: 0.7450
# Training epoch: 7, Training loss: 0.5318, Train accuracy: 0.8552, Test accuracy: 0.7661
# Training epoch: 8, Training loss: 0.4946, Train accuracy: 0.8733, Test accuracy: 0.7703

# %%
plt.plot(multi_cnn_train_accuracy)
plt.plot(multi_cnn_test_accuracy)
plt.ylim(ymin=0.5, ymax=1.01)
plt.title("The accuracy of multi-channel CNN model")
plt.legend(["train", "test"])

# %% [markdown]
# #### 预测模型

# %%
# 在test上的准确率
with tf.Session() as sess:
    saver.restore(sess, "../dataset/checkpoints/multi_cnn")
    
    total_correct = sess.run(accuracy,
                             feed_dict={inputs: x_test, targets: y_test})

    print("The LSTM model accuracy on test set: {:.2f}%".format(100 * total_correct / x_test.shape[0]))
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 763
# INFO:tensorflow:Restoring parameters from ../dataset/checkpoints/multi_cnn
# The LSTM model accuracy on test set: 77.07%
